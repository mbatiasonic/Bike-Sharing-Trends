# %% [markdown]
# <a href="https://colab.research.google.com/github/mbatiasonic/Bike-Sharing-Trends/blob/main/Copy_of_DeepForest_Training_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DeepForest Training Walkthrough(CPU/GPU)
#   - For GPU implementation.
#       1. Select **Runtime** > Change **runtime type** and Select GPU as Hardware accelerator.

# %%
#install the package, on colab make sure to upgrade existing packages. This is not needed in a clean env.
! pip install --upgrade deepforest
# Out:
# Collecting deepforest
#   Downloading deepforest-1.3.3-py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 64.1 MB/s eta 0:00:00
# Requirement already satisfied: albumentations>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from deepforest) (1.3.1)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from deepforest) (0.13.2)
# Collecting imagecodecs (from deepforest)
#   Downloading imagecodecs-2024.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from deepforest) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepforest) (1.25.2)
# Requirement already satisfied: opencv-python>=4.5.4 in /usr/local/lib/python3.10/dist-packages (from deepforest) (4.8.0.76)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from deepforest) (2.0.3)
# Requirement already satisfied: Pillow>6.2.0 in /usr/local/lib/python3.10/dist-packages (from deepforest) (9.4.0)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.10/dist-packages (from deepforest) (4.2.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from deepforest) (2.0.7)
# Collecting pytorch-lightning>=1.5.8 (from deepforest)
#   Downloading pytorch_lightning-2.2.5-py3-none-any.whl (802 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.3/802.3 kB 57.4 MB/s eta 0:00:00
# Collecting rasterio (from deepforest)
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 48.6 MB/s eta 0:00:00
# Collecting recommonmark (from deepforest)
#   Downloading recommonmark-0.7.1-py2.py3-none-any.whl (10 kB)
# Collecting rtree (from deepforest)
#   Downloading Rtree-1.2.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (535 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.2/535.2 kB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>1.5 in /usr/local/lib/python3.10/dist-packages (from deepforest) (1.11.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from deepforest) (1.16.0)
# Collecting slidingwindow (from deepforest)
#   Downloading slidingwindow-0.0.14-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.10/dist-packages (from deepforest) (5.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepforest) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.13 in /usr/local/lib/python3.10/dist-packages (from deepforest) (0.18.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepforest) (4.66.4)
# Collecting xmltodict (from deepforest)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest) (4.10.0.82)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=1.5.8->deepforest)
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest) (4.12.2)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning>=1.5.8->deepforest)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->deepforest) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepforest) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepforest) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->deepforest)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->deepforest)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->deepforest)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->deepforest)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->deepforest)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->deepforest)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->deepforest)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->deepforest)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->deepforest)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->deepforest)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->deepforest)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->deepforest)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 73.3 MB/s eta 0:00:00
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest) (1.9.6)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest) (2.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest) (3.1.2)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from progressbar2->deepforest) (3.8.2)
# Collecting affine (from rasterio->deepforest)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->deepforest)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest) (67.7.2)
# Collecting commonmark>=0.8.1 (from recommonmark->deepforest)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.10/dist-packages (from recommonmark->deepforest) (0.18.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.0.7)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (2.15.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (0.7.16)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest) (2.31.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from slidingwindow->deepforest) (5.9.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (3.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->deepforest) (2.1.5)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations>=1.0.0->deepforest) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest) (2.0.7)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest) (2024.5.22)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest) (1.6.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepforest) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest) (4.0.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.0->deepforest) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.0->deepforest) (3.5.0)
# Installing collected packages: commonmark, xmltodict, snuggs, slidingwindow, rtree, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, imagecodecs, affine, rasterio, nvidia-cusparse-cu12, nvidia-cudnn-cu12, recommonmark, nvidia-cusolver-cu12, torchmetrics, pytorch-lightning, deepforest
# Successfully installed affine-2.4.0 commonmark-0.9.1 deepforest-1.3.3 imagecodecs-2024.6.1 lightning-utilities-0.11.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pytorch-lightning-2.2.5 rasterio-1.3.10 recommonmark-0.7.1 rtree-1.2.0 slidingwindow-0.0.14 snuggs-1.4.7 torchmetrics-1.4.0.post0 xmltodict-0.13.0

# %%
pip install git+https://github.com/weecology/DeepForest.git
# Out:
# Collecting git+https://github.com/weecology/DeepForest.git
#   Cloning https://github.com/weecology/DeepForest.git to /tmp/pip-req-build-7_auzvql
#   Running command git clone --filter=blob:none --quiet https://github.com/weecology/DeepForest.git /tmp/pip-req-build-7_auzvql
#   Resolved https://github.com/weecology/DeepForest.git to commit 670afd57b40e15f06fe175864ff54fbeb91f9feb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: albumentations>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.3.1)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (0.13.2)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (2024.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.25.2)
# Requirement already satisfied: opencv-python>=4.5.4 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (4.8.0.76)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (2.0.3)
# Requirement already satisfied: Pillow>6.2.0 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (9.4.0)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (4.2.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (2.0.7)
# Requirement already satisfied: pytorch-lightning>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (2.2.5)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.3.10)
# Requirement already satisfied: recommonmark in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (0.7.1)
# Requirement already satisfied: rtree in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.2.0)
# Requirement already satisfied: scipy>1.5 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.11.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (1.16.0)
# Requirement already satisfied: slidingwindow in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (0.0.14)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (5.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.13 in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (0.18.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (4.66.4)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from deepforest==1.3.3) (0.13.0)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest==1.3.3) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest==1.3.3) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest==1.3.3) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=1.0.0->deepforest==1.3.3) (4.10.0.82)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest==1.3.3) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest==1.3.3) (1.4.0.post0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest==1.3.3) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest==1.3.3) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.5.8->deepforest==1.3.3) (0.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepforest==1.3.3) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->deepforest==1.3.3) (12.5.40)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest==1.3.3) (1.9.6)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest==1.3.3) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas->deepforest==1.3.3) (2.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest==1.3.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest==1.3.3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepforest==1.3.3) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest==1.3.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest==1.3.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest==1.3.3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest==1.3.3) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepforest==1.3.3) (3.1.2)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from progressbar2->deepforest==1.3.3) (3.8.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (2024.6.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->deepforest==1.3.3) (67.7.2)
# Requirement already satisfied: commonmark>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from recommonmark->deepforest==1.3.3) (0.9.1)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.10/dist-packages (from recommonmark->deepforest==1.3.3) (0.18.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.0.7)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (2.15.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (0.7.16)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->deepforest==1.3.3) (2.31.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from slidingwindow->deepforest==1.3.3) (5.9.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (3.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->deepforest==1.3.3) (2.1.5)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations>=1.0.0->deepforest==1.3.3) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest==1.3.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest==1.3.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->deepforest==1.3.3) (2.0.7)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest==1.3.3) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest==1.3.3) (2024.5.22)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=1.0.0->deepforest==1.3.3) (1.6.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepforest==1.3.3) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.8->deepforest==1.3.3) (4.0.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.0->deepforest==1.3.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=1.0.0->deepforest==1.3.3) (3.5.0)

# %%
#load the modules
import os
import time
import torch
import numpy as np
from deepforest import main
from deepforest import get_data
from deepforest import utilities
from deepforest import preprocess

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#convert hand annotations from xml into retinanet format
#The get_data function is only needed when fetching sample package data
YELL_xml = get_data("/content/drive/MyDrive/overlap/DJI_0175.xml")
annotation = utilities.xml_to_annotations(YELL_xml)
annotation.head()
# Out:
#      image_path  xmin  ymin  xmax  ymax label
# 0  DJI_0175.JPG   259    91   345   173  Tree
# 1  DJI_0175.JPG    62   412   179   512  Tree
# 2  DJI_0175.JPG   246   304   317   365  Tree
# 3  DJI_0175.JPG   833   784   941   881  Tree
# 4  DJI_0175.JPG  1202   845  1320   952  Tree

# %%
def check_and_fix_bboxes(df):
    """
    Check and fix bounding boxes in the DataFrame.
    """
    invalid_bboxes = []
    for index, row in df.iterrows():
        xmin, ymin, xmax, ymax = row['xmin'], row['ymin'], row['xmax'], row['ymax']
        if xmax <= xmin or ymax <= ymin:
            invalid_bboxes.append(index)
            # Fix the bbox by setting some default values or removing the entry
            df.at[index, 'xmax'] = max(xmax, xmin + 0.01)  # Example fix
            df.at[index, 'ymax'] = max(ymax, ymin + 0.01)  # Example fix

    print(f"Found {len(invalid_bboxes)} invalid bounding boxes.")
    return df

# %%
annotation = utilities.xml_to_annotations(YELL_xml)

# %%
# Check and fix the bounding boxes
annotations= check_and_fix_bboxes(annotation)
# Out:
# Found 1 invalid bounding boxes.

# %%
# Save the corrected annotations
annotations.to_xml("/content/drive/MyDrive/overlap/DJI_0175_1.xml", index=False)

# %%
#load the image file corresponding to the annotaion file
YELL_train = get_data("/content/drive/MyDrive/overlap/DJI_0175.JPG")
image_path = os.path.dirname(YELL_train)
#Write converted dataframe to file. Saved alongside the images
annotation.to_csv(os.path.join(image_path,"train_example.csv"), index=False)

# %% [markdown]
# ## Prepare Training and Validation Data
#   - 75% Training Data
#   - 25% Validation Data

# %%
#Find annotation path
annotation_path = os.path.join(image_path,"train_example.csv")
#crop images will save in a newly created directory
#os.mkdir(os.getcwd(),'train_data_folder')
crop_dir = os.path.join(os.getcwd(),'train_data_folder')
train_annotations= preprocess.split_raster(path_to_raster=YELL_train,
                                 annotations_file=annotation_path,
                                 base_dir=crop_dir,
                                 patch_size=800,
                                 patch_overlap=0.05)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
#Split image crops into training and test. Normally these would be different tiles! Just as an example.
image_paths = train_annotations.image_path.unique()
#split 25% validation annotation
valid_paths = np.random.choice(image_paths, int(len(image_paths)*0.25) )
valid_annotations = train_annotations.loc[train_annotations.image_path.isin(valid_paths)]
train_annotations = train_annotations.loc[~train_annotations.image_path.isin(valid_paths)]

# %%
#View output
train_annotations.head()
print("There are {} training crown annotations".format(train_annotations.shape[0]))
print("There are {} test crown annotations".format(valid_annotations.shape[0]))

#save to file and create the file dir
annotations_file= os.path.join(crop_dir,"train.csv")
validation_file= os.path.join(crop_dir,"valid.csv")
#Write window annotations file without a header row, same location as the "base_dir" above.
train_annotations.to_csv(annotations_file,index=False)
valid_annotations.to_csv(validation_file,index=False)
# Out:
# There are 384 training crown annotations
# There are 139 test crown annotations

# %%
annotations_file
# Out:
# '/content/train_data_folder/train.csv'

# %% [markdown]
# ## Training & Evaluating Using CPU

# %%
#initial the model and change the corresponding config file
m = main.deepforest()
m.config["train"]["csv_file"] = annotations_file
m.config["train"]["root_dir"] = os.path.dirname(annotations_file)
#Since this is a demo example and we aren't training for long, only show the higher quality boxes
m.config["score_thresh"] = 0.4
m.config["train"]['epochs'] = 2
m.config["validation"]["csv_file"] = validation_file
m.config["validation"]["root_dir"] = os.path.dirname(validation_file)
#create a pytorch lighting trainer used to training
m.create_trainer()
#load the lastest release model
m.use_release()
# Out:
# Reading config file: /usr/local/lib/python3.10/dist-packages/deepforest/data/deepforest_config.yml
# Downloading: "https://download.pytorch.org/models/retinanet_resnet50_fpn_coco-eeacb38b.pth" to /root/.cache/torch/hub/checkpoints/retinanet_resnet50_fpn_coco-eeacb38b.pth
# 100%|██████████| 130M/130M [00:01<00:00, 131MB/s]
# No validation file provided. Turning off validation loop
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a7548447b583> in <cell line: 3>()
#       1 #initial the model and change the corresponding config file
#       2 m = main.deepforest()
# ----> 3 m.config["train"]["csv_file"] = annotations_file
#       4 m.config["train"]["root_dir"] = os.path.dirname(annotations_file)
#       5 #Since this is a demo example and we aren't training for long, only show the higher quality boxes
#
# NameError: name 'annotations_file' is not defined

# %%
start_time = time.time()
m.trainer.fit(m)
print(f"--- Training on CPU: {(time.time() - start_time):.2f} seconds ---")

# %%
m.get_transform

# %%
#create a directory to save the predict image
save_dir = os.path.join(os.getcwd(),'pred_result')
try:
  os.mkdir(save_dir)
except FileExistsError:
  pass
results = m.evaluate(annotations_file, os.path.dirname(annotations_file), iou_threshold = 0.4, savedir = save_dir)

# %% [markdown]
# ## Training & Evaluating Using GPU

# %%
#initial the model and change the corresponding config file
m = main.deepforest()
m.config['gpus'] = '-1' #move to GPU and use all the GPU resources
m.config["train"]["csv_file"] = annotations_file
m.config["train"]["root_dir"] = os.path.dirname(annotations_file)
m.config["score_thresh"] = 0.4
m.config["train"]['epochs'] = 3
m.config["validation"]["csv_file"] = validation_file
m.config["validation"]["root_dir"] = os.path.dirname(validation_file)
#create a pytorch lighting trainer used to training
m.create_trainer()
#load the lastest release model
m.use_release()
# Out:
# Reading config file: /usr/local/lib/python3.10/dist-packages/deepforest/data/deepforest_config.yml
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# No validation file provided. Turning off validation loop
# Model from DeepForest release https://github.com/weecology/DeepForest/releases/tag/1.0.0 was already downloaded. Loading model from file.
# Loading pre-built model: https://github.com/weecology/DeepForest/releases/tag/1.0.0

# %%
start_time = time.time()
m.trainer.fit(m)
print(f"--- Training on GPU: {(time.time() - start_time):.2f} seconds ---")

# Save the model
torch.save(m.state_dict(), '/content/drive/MyDrive/overlap/Trainedmodel/model.pth')
print("Model saved successfully.")
# Out:
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name       | Type                  | Params
# -----------------------------------------------------
# 0 | model      | RetinaNet             | 32.1 M
# 1 | iou_metric | IntersectionOverUnion | 0
# 2 | mAP_metric | MeanAveragePrecision  | 0
# -----------------------------------------------------
# 31.9 M    Trainable params
# 222 K     Non-trainable params
# 32.1 M    Total params
# 128.592   Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/data.py:77: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=3` reached.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# --- Training on GPU: 34.88 seconds ---
# Model saved successfully.

# %%
#save the prediction result to a prediction folder
save_dir = os.path.join(os.getcwd(),'pred_result')
try:
  os.mkdir(save_dir)
except FileExistsError:
  pass
results = m.evaluate(annotations_file, os.path.dirname(annotations_file), iou_threshold = 0.4, savedir= save_dir)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
results
# Out:
# {'results':     prediction_id  truth_id       IoU     score  xmin  xmax  ymin   ymax  \
#  0               2         0  0.894841  0.313452   259   345    91  173.0
#  1               7         1  0.739404  0.200498    62   179   412  512.0
#  2               9         2  0.400796  0.180802   246   317   304  365.0
#  3              10         3  0.321714  0.180559     0    89   591  800.0
#  0               5         0  0.947755  0.609846     0    72    89  160.0
#  ..            ...       ...       ...       ...   ...   ...   ...    ...
#  4               4         4  0.755244  0.605225   683   800     0   68.0
#  5               5         5  0.706389  0.522825   507   606   646  722.0
#  6              14         6  0.605334  0.331703   495   584   725  796.0
#  7               0         7  0.825723  0.661273   413   494    28   93.0
#  8               7         8  0.000000  0.468739   532   604   579  643.0
#
#     predicted_label true_label       image_path  match
#  0             Tree       Tree   DJI_0175_0.png   True
#  1             Tree       Tree   DJI_0175_0.png   True
#  2             Tree       Tree   DJI_0175_0.png   True
#  3             Tree       Tree   DJI_0175_0.png  False
#  0             Tree       Tree  DJI_0175_10.png   True
#  ..             ...        ...              ...    ...
#  4             Tree       Tree   DJI_0175_9.png   True
#  5             Tree       Tree   DJI_0175_9.png   True
#  6             Tree       Tree   DJI_0175_9.png   True
#  7             Tree       Tree   DJI_0175_9.png   True
#  8             Tree       Tree   DJI_0175_9.png  False
#
#  [384 rows x 12 columns],
#  'box_precision': 0.47229334376121096,
#  'box_recall': 0.9705678012695557,
#  'class_recall':    label  recall  precision  size
#  0      0     1.0        1.0   374,
#  'predictions':            xmin        ymin        xmax        ymax label     score  \
#  0    397.639404    8.905655  489.394104   83.571770  Tree  0.379405
#  1    352.378082  459.155273  442.018219  533.235962  Tree  0.320808
#  2    256.676971   88.844841  349.745087  173.521851  Tree  0.313452
#  3    379.169708  217.592636  488.398529  303.931915  Tree  0.292505
#  4    395.871948  118.759949  487.873779  196.392609  Tree  0.280825
#  ..          ...         ...         ...         ...   ...       ...
#  796  214.637024  693.625122  261.707764  736.548340  Tree  0.217259
#  797  748.386902  527.199402  800.000000  579.757263  Tree  0.211491
#  798  763.201111  659.584473  800.000000  701.125000  Tree  0.166220
#  799  234.541168  207.764893  276.201294  242.677704  Tree  0.147616
#  800  396.667480  479.031738  449.900391  524.487061  Tree  0.123888
#
#            image_path
#  0     DJI_0175_0.png
#  1     DJI_0175_0.png
#  2     DJI_0175_0.png
#  3     DJI_0175_0.png
#  4     DJI_0175_0.png
#  ..               ...
#  796  DJI_0175_38.png
#  797  DJI_0175_38.png
#  798  DJI_0175_38.png
#  799  DJI_0175_38.png
#  800  DJI_0175_38.png
#
#  [801 rows x 7 columns]}

# %%
results['box_precision']
# Out:
# 0.47229334376121096

# %%
results["box_recall"]
# Out:
# 0.9705678012695557

# %%
results["results"]
# Out:
#     prediction_id  truth_id       IoU     score  xmin  xmax  ymin   ymax  \
# 0               2         0  0.894841  0.313452   259   345    91  173.0
# 1               7         1  0.739404  0.200498    62   179   412  512.0
# 2               9         2  0.400796  0.180802   246   317   304  365.0
# 3              10         3  0.321714  0.180559     0    89   591  800.0
# 0               5         0  0.947755  0.609846     0    72    89  160.0
# ..            ...       ...       ...       ...   ...   ...   ...    ...
# 4               4         4  0.755244  0.605225   683   800     0   68.0
# 5               5         5  0.706389  0.522825   507   606   646  722.0
# 6              14         6  0.605334  0.331703   495   584   725  796.0
# 7               0         7  0.825723  0.661273   413   494    28   93.0
# 8               7         8  0.000000  0.468739   532   604   579  643.0
#
#    predicted_label true_label       image_path  match
# 0             Tree       Tree   DJI_0175_0.png   True
# 1             Tree       Tree   DJI_0175_0.png   True
# 2             Tree       Tree   DJI_0175_0.png   True
# 3             Tree       Tree   DJI_0175_0.png  False
# 0             Tree       Tree  DJI_0175_10.png   True
# ..             ...        ...              ...    ...
# 4             Tree       Tree   DJI_0175_9.png   True
# 5             Tree       Tree   DJI_0175_9.png   True
# 6             Tree       Tree   DJI_0175_9.png   True
# 7             Tree       Tree   DJI_0175_9.png   True
# 8             Tree       Tree   DJI_0175_9.png  False
#
# [384 rows x 12 columns]

# %%
results["class_recall"]
# Out:
#    label  recall  precision  size
# 0      0     1.0        1.0   374

# %%
# import torch
# # Save the trained model
# torch.save(m.model.state_dict(), "/content/drive/MyDrive/overlap/Trainedmodel/model.pth")

# %%
import collections
# Load the trained model
loaded_model = main.deepforest()
loaded_model.use_release()
state_dict = torch.load("/content/drive/MyDrive/overlap/Trainedmodel/model.pth")

# Remove the 'model.' prefix from the state_dict keys
new_state_dict = collections.OrderedDict([(k[6:], v) if k.startswith('model.') else (k, v) for k, v in state_dict.items()])

loaded_model.model.load_state_dict(new_state_dict)  # Load the modified state_dict
# Out:
# Reading config file: /usr/local/lib/python3.10/dist-packages/deepforest/data/deepforest_config.yml
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# No validation file provided. Turning off validation loop
# Model from DeepForest release https://github.com/weecology/DeepForest/releases/tag/1.0.0 was already downloaded. Loading model from file.
# Loading pre-built model: https://github.com/weecology/DeepForest/releases/tag/1.0.0
# <All keys matched successfully>

# %%
# # Load the trained model
# loaded_model = main.deepforest()
# loaded_model.use_release()
# state_dict = torch.load("/content/drive/MyDrive/overlap/Trainedmodel/model.pth")
# loaded_model.model.load_state_dict(state_dict)

# %%
# Conduct tests on new images from your surroundings
test_image =get_data("/content/drive/MyDrive/overlap/DJI_0176.JPG")
detections = loaded_model.predict_tile(test_image, return_plot = False, patch_size=1000, patch_overlap=0.25)
print(detections)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Predicting: |          | 0/? [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 1090 predictions in overlapping windows, applying non-max supression
# 636 predictions kept after non-max suppression
#        xmin    ymin    xmax    ymax label     score    image_path
# 0    4863.0  1083.0  4981.0  1178.0  Tree  0.872770  DJI_0176.JPG
# 1    4791.0  2333.0  4932.0  2459.0  Tree  0.868810  DJI_0176.JPG
# 2    1257.0   654.0  1359.0   736.0  Tree  0.857766  DJI_0176.JPG
# 3    3792.0  1717.0  3891.0  1805.0  Tree  0.848839  DJI_0176.JPG
# 4    2428.0   810.0  2532.0   898.0  Tree  0.845845  DJI_0176.JPG
# ..      ...     ...     ...     ...   ...       ...           ...
# 631  4655.0  2798.0  4706.0  2843.0  Tree  0.115980  DJI_0176.JPG
# 632  4506.0  2030.0  4573.0  2085.0  Tree  0.114912  DJI_0176.JPG
# 633   661.0  1304.0   714.0  1350.0  Tree  0.112825  DJI_0176.JPG
# 634  1597.0  2820.0  1659.0  2874.0  Tree  0.111513  DJI_0176.JPG
# 635  5065.0  2943.0  5134.0  3007.0  Tree  0.104547  DJI_0176.JPG
#
# [636 rows x 7 columns]
